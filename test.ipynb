# %%
from imgpro.utils import io, plot
from imgpro.processing import combination, transformation

# %%
img1 = io.read_image('sample_img/green_forest.jpg')
img2 = io.read_image('sample_img/autumn_forest.jpg')

# %%
plot.plot_image(img1)
plot.plot_image(img2)

# %%
result_img = combination.transfer_histogram(img1, img2)
plot.plot_result(img1, img2, result_img)
